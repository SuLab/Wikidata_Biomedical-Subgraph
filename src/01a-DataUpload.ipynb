# %% [markdown]
# ### Confirmations
# - [Mar 17 2022] .ndjson files all have the appropriate count
# - [Jul 5 2022] .ndjson files all have the appropriate count
# - [Jul 8 2022] nodes.csv updated with appropriate headings and count
# <br><br>
#
# - check for NaNs

# %% [markdown]
# ### Checks
# - Ensure a package is loaded using 'pip install'

# %%
import pandas as pd
from io import StringIO

import time 
from datetime import datetime

import csv

# %% [markdown]
# ## nodes.csv

# %%
# Read in files (ndjson or csv)

import pandas as pd
import glob

# getting csv files from the folder MyProject
path = "/home/sulhasan/Jan3-2022/files/csv"

# read all the files with extension .csv
filenames = glob.glob(path + "*.csv")
print('File names:', filenames)
# Out:
# File names: []

# %%
import pandas as pd
import glob

path = "/home/sulhasan/Jan3-2022/files/csv"
filenames = glob.glob(path + "/*.csv")

# Create time stamp
timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 
start_time = time.time()

for file in filenames:
    print(pd.read_csv(file, sep="\t")) # read .csv, separate by tab

end_time = time.time() #  remote
print((end_time - start_time)/60, "to read in these .csv files")


# time stamp
# for loop
# read .csv file, separate by tab
# print first 3 lines of file (by correct name)
# end (fully constructed nodes.csv) *NaN

# file is ready by name I want
## finalchemicalhazard = chemicalhazard.csv 
## final* = pd.read_csv('files/csv/chemicalhazard.csv', sep="\t")
# nodes.csv pd.concat (end of for)
# Out:
#          :ID          ,:LABEL                    ,name
# 0   Q7559033  Chemical Hazard         solvent exposure
# 1  Q21973551  Chemical Hazard  sulfur mustard exposure
# 2  Q55696142  Chemical Hazard                      NaN
#              :ID  ,:LABEL                                              ,name
# 0         Q68854  Disease                                          snakebite
# 1        Q119280  Disease                            medullary sponge kidney
# 2        Q143790  Disease                                Alien hand syndrome
# 3        Q188605  Disease                                pulmonary emphysema
# 4        Q188611  Disease                                          hypomania
# ...          ...      ...                                                ...
# 5508  Q108661111  Disease        Monoclonal gammopathy of renal significance
# 5509  Q108668003  Disease                Sclerosing epithelioid fibrosarcoma
# 5510  Q109676510  Disease                   glycogen storage disease type 0A
# 5511  Q110064502  Disease  Dermatofibrosarcoma protuberans, fibrosarcomatous
# 5512  Q110090006  Disease                       autoimmune hemorrhaphilia 13
#
# [5513 rows x 3 columns]
#           :ID       ,:LABEL                                              ,name
# 0   Q24722105  Binding Site                     Germin, manganese binding site
# 1   Q24725852  Binding Site  Orn/DAP/Arg decarboxylase 2, pyridoxal-phospha...
# 2   Q24725899  Binding Site                  Leghaemoglobin, iron-binding site
# 3   Q24726514  Binding Site      PPM-type phosphatase, divalent cation binding
# 4   Q24726869  Binding Site  Serine hydroxymethyltransferase, pyridoxal pho...
# ..        ...           ...                                                ...
# 72  Q24776092  Binding Site          Beta tubulin, autoregulation binding site
# 73  Q24780148  Binding Site  Cytochrome c oxidase, subunit I, copper-bindin...
# 74  Q24784373  Binding Site                     IQ motif, EF-hand binding site
# 75  Q24787492  Binding Site  Alanine racemase, pyridoxal-phosphate attachme...
# 76  Q24788571  Binding Site  Crossover junction endodeoxyribonuclease RuvC,...
#
# [77 rows x 3 columns]
#              :ID             ,:LABEL  \
# 0      Q21694734  Biological Pathway
# 1      Q28031274  Biological Pathway
# 2      Q29891990  Biological Pathway
# 3      Q29892200  Biological Pathway
# 4      Q30039518  Biological Pathway
# ...          ...                 ...
# 3479  Q109863610  Biological Pathway
# 3480  Q109863844  Biological Pathway
# 3481  Q109864661  Biological Pathway
# 3482  Q109865212  Biological Pathway
# 3483  Q109865661  Biological Pathway
#
#                                                   ,name
# 0                                  Vitamin D metabolism
# 1                        Glycolysis and gluconeogenesis
# 2                                MAPK signaling pathway
# 3                                            Cell cycle
# 4                                        Bile secretion
# ...                                                 ...
# 3479  Modulators of TCR signaling and T cell activation
# 3480        Network map of SARS-CoV-2 signaling pathway
# 3481                                      FOXA2 pathway
# 3482  Interactions of natural killer cells in pancre...
# 3483                                 Burn wound healing
#
# [3484 rows x 3 columns]
#               :ID             ,:LABEL  \
# 0           Q1057  Biological Process
# 1          Q99974  Biological Process
# 2         Q134624  Biological Process
# 3         Q173432  Biological Process
# 4         Q179217  Biological Process
# ...           ...                 ...
# 41842  Q106519019  Biological Process
# 41843  Q106519028  Biological Process
# 41844  Q106519049  Biological Process
# 41845  Q106519116  Biological Process
# 41846  Q106586493  Biological Process
#
#                                                ,name
# 0                                         metabolism
# 1                                         mycorrhiza
# 2                                        pollination
# 3                               asexual reproduction
# 4                                  blood coagulation
# ...                                              ...
# 41842    RHOU binds effectors at the plasma membrane
# 41843  RHOD binds effectors at the endosome membrane
# 41844                                 RND3 binds GTP
# 41845                      RHOT1 GEFs activate RHOT1
# 41846                      cell population expansion
#
# [41847 rows x 3 columns]
#               :ID ,:LABEL                           ,name
# 0          Q30555    Gene                  proto-oncogene
# 1         Q286987    Gene                           ABCA1
# 2         Q390540    Gene                           EDNRA
# 3         Q417743    Gene                              PC
# 4         Q508356    Gene                          COL8A1
# ...           ...     ...                             ...
# 170413  Q22567117    Gene    hypothetical protein YPO2902
# 170414  Q22567126    Gene    hypothetical protein YPO3019
# 170415  Q22567136    Gene    hypothetical protein YPO3151
# 170416  Q22567144    Gene    hypothetical protein YPO3232
# 170417  Q22567147    Gene  amino acid transporter YPO3264
#
# [170418 rows x 3 columns]
#             :ID  ,:LABEL                          ,name
# 0       Q188611  Symptom                      hypomania
# 1       Q653197  Symptom                           rash
# 2       Q936070  Symptom                        trismus
# 3      Q1806356  Symptom                       algiuria
# 4      Q1975146  Symptom                    obtundation
# ..          ...      ...                            ...
# 324   Q56233069  Symptom                  Tetanus triad
# 325   Q58145981  Symptom                    apragmatism
# 326   Q67135693  Symptom  rejection sensitive dysphoria
# 327   Q96470164  Symptom            identity alteration
# 328  Q107355983  Symptom          Paradoxical breathing
#
# [329 rows x 3 columns]
#            :ID               ,:LABEL                        ,name
# 0        Q7365  Anatomical Structure                 muscle organ
# 1        Q9377  Anatomical Structure                       kidney
# 2        Q9609  Anatomical Structure                         vein
# 3        Q9620  Anatomical Structure                        nerve
# 4        Q9635  Anatomical Structure                        mouth
# ..         ...                   ...                          ...
# 532  Q29718860  Anatomical Structure  posterior semicircular duct
# 533  Q29729440  Anatomical Structure        anterior bony ampulla
# 534  Q30026965  Anatomical Structure          conjunctival fornix
# 535  Q30104011  Anatomical Structure               cardiac septum
# 536  Q30320470  Anatomical Structure               scleral stroma
#
# [537 rows x 3 columns]
#                :ID  ,:LABEL                                              ,name
# 0           Q63398  Protein                                     Chromogranin B
# 1          Q171604  Protein             Hydroxysteroid 11-beta dehydrogenase 1
# 2          Q205042  Protein  Atypical chemokine receptor 1 (Duffy blood group)
# 3          Q223739  Protein                                             leptin
# 4          Q259292  Protein                     7-dehydrocholesterol reductase
# ...            ...      ...                                                ...
# 987631  Q109697489  Protein  Rab-GAP TBC domain-containing protein CELE_T24...
# 987632  Q109715419  Protein            Transmembrane channel-like Dmel_CG46121
# 987633  Q109715494  Protein    Zinc finger DHHC-type containing 8 Dmel_CG34449
# 987634  Q109735274  Protein  Sulfotransferase family 2A, dehydroepiandroste...
# 987635  Q110412267  Protein                                                NaN
#
# [987636 rows x 3 columns]
#             :ID           ,:LABEL                             ,name
# 0      Q2007385  Structural Motif                               NaN
# 1      Q5445279  Structural Motif                   Ferredoxin fold
# 2     Q19903500  Structural Motif                   Beta bulge loop
# 3     Q24721913  Structural Motif                      BRCA2 repeat
# 4     Q24722066  Structural Motif                   Titin, Z repeat
# ..          ...               ...                               ...
# 348   Q81497541  Structural Motif  Dextranase, beta solenoid repeat
# 349   Q81497557  Structural Motif                 Importin repeat 4
# 350   Q81497568  Structural Motif        Homing endonuclease repeat
# 351  Q103839955  Structural Motif                        QPE repeat
# 352  Q103840410  Structural Motif    Plasmodium repeat of length 46
#
# [353 rows x 3 columns]
#               :ID         ,:LABEL  \
# 0        Q1829843  Protein Domain
# 1        Q5009288  Protein Domain
# 2        Q6718295  Protein Domain
# 3        Q7388668  Protein Domain
# 4       Q24719548  Protein Domain
# ...           ...             ...
# 11704  Q110196074  Protein Domain
# 11705  Q110196100  Protein Domain
# 11706  Q110196226  Protein Domain
# 11707  Q110196228  Protein Domain
# 11708  Q110196296  Protein Domain
#
#                                                    ,name
# 0                                            Bromodomain
# 1                                             CBS domain
# 2                               mSin3 interaction domain
# 3                                            SANT domain
# 4                  Rad9-like Rad53-binding domain, fungi
# ...                                                  ...
# 11704                           QcrA subunit, N-terminal
# 11705  Glycerol-3-phosphate acyltransferase-like, C-t...
# 11706                 Domain of unknown function DUF6379
# 11707                      Effector-associated domain 11
# 11708                           Neutrophin-3, N-terminal
#
# [11709 rows x 3 columns]
#              :ID             ,:LABEL  \
# 0       Q1012651  Molecular Function
# 1      Q14358843  Molecular Function
# 2      Q14599285  Molecular Function
# 3      Q14633869  Molecular Function
# 4      Q14633877  Molecular Function
# ...          ...                 ...
# 10892  Q66986422  Molecular Function
# 10893  Q69567961  Molecular Function
# 10894  Q70535569  Molecular Function
# 10895  Q70535594  Molecular Function
# 10896  Q70551215  Molecular Function
#
#                                                    ,name
# 0                                ribonuclease P activity
# 1      oxidoreductase activity, acting on paired dono...
# 2      oxidoreductase activity, acting on the CH-CH g...
# 3                       ubiquitin protein ligase binding
# 4                                      chaperone binding
# ...                                                  ...
# 10892         phosphatidylethanolamine floppase activity
# 10893               modulation of antimicrobial activity
# 10894  L-gamma-glutamyl-L-propargylglycine hydroxylas...
# 10895                chloride:proton antiporter activity
# 10896       RNA NAD-cap (NAD-forming) hydrolase activity
#
# [10897 rows x 3 columns]
#            :ID      ,:LABEL                                              ,name
# 0    Q24721060  Active Site     4-hydroxybenzoyl-CoA thioesterase, active site
# 1    Q24721301  Active Site     DNA/RNA non-specific endonuclease, active site
# 2    Q24721995  Active Site  Orotidine 5'-phosphate decarboxylase, active site
# 3    Q24740369  Active Site            Adenylosuccinate synthase,  active site
# 4    Q24770253  Active Site                  Membrane dipeptidase, active site
# ..         ...          ...                                                ...
# 127  Q24782307  Active Site     Glucose-6-phosphate dehydrogenase, active site
# 128  Q24784845  Active Site            DNA topoisomerase, type IA, active site
# 129  Q24785830  Active Site  Peptidase S26A, signal peptidase I, lysine act...
# 130  Q24786354  Active Site          Schiff base-forming aldolase, active site
# 131  Q24788217  Active Site                        ClpP, histidine active site
#
# [132 rows x 3 columns]
#              :ID             ,:LABEL                       ,name
# 0         Q29548  Cellular Component             plasma membrane
# 1         Q30869  Cellular Component                   nucleolus
# 2         Q61333  Cellular Component                X chromosome
# 3        Q126223  Cellular Component       immunological synapse
# 4        Q180951  Cellular Component                   chromatin
# ...          ...                 ...                         ...
# 4130   Q70535588  Cellular Component     curli secretion complex
# 4131   Q70551253  Cellular Component  cellular anatomical entity
# 4132   Q70551687  Cellular Component          DNA gyrase complex
# 4133   Q70552234  Cellular Component      decoy receptor complex
# 4134  Q107640789  Cellular Component            Type IV filament
#
# [4135 rows x 3 columns]
#              :ID   ,:LABEL                   ,name
# 0          Q2546  Compound       potassium bromide
# 1         Q19052  Compound           silver iodide
# 2         Q32703  Compound     aminomethylpropanol
# 3         Q41353  Compound            (-)-urobilin
# 4         Q43656  Compound             cholesterol
# ...          ...       ...                     ...
# 1089287  Q184967  Compound            Zeise's salt
# 1089288  Q188017  Compound              L-tyrosine
# 1089289  Q189335  Compound               cementite
# 1089290  Q190227  Compound        sodium carbonate
# 1089291  Q190865  Compound  potassium permanganate
#
# [1089292 rows x 3 columns]
#             :ID           ,:LABEL                              ,name
# 0     Q28371440  Sequence Variant                       DNMT3A P904L
# 1     Q28444966  Sequence Variant                EGFR Overexpression
# 2     Q28445004  Sequence Variant                NT5E OVEREXPRESSION
# 3     Q28445063  Sequence Variant                  CDKN1B EXPRESSION
# 4     Q28445091  Sequence Variant                   ABCB1 EXPRESSION
# ..          ...               ...                                ...
# 691   Q38153318  Sequence Variant  chr7:g.55259524T>G (EGFR:p.L861R)
# 692   Q38153323  Sequence Variant  chr6:g.18139228C>T (TPMT:p.A154T)
# 693   Q38153324  Sequence Variant  chr6:g.18134115G>C (TPMT:p.A167G)
# 694   Q45023763  Sequence Variant                            C10873T
# 695  Q105669091  Sequence Variant               ABCB1 Overexpression
#
# [696 rows x 3 columns]
#            :ID            ,:LABEL                   ,name
# 0      Q120569  Medical Specialty        gastroenterology
# 1      Q123028  Medical Specialty              pediatrics
# 2      Q162555  Medical Specialty                oncology
# 3      Q177635  Medical Specialty              nephrology
# 4      Q188449  Medical Specialty            neurosurgery
# ..         ...                ...                     ...
# 251  Q11865729  Medical Specialty                podiatry
# 252  Q17143415  Medical Specialty         hematopathology
# 253  Q31841220  Medical Specialty  Geriatric traumatology
# 254  Q45090931  Medical Specialty      functional surgery
# 255  Q47036619  Medical Specialty            bone surgery
#
# [256 rows x 3 columns]
#               :ID         ,:LABEL  \
# 0         Q408477  Protein Family
# 1         Q409145  Protein Family
# 2         Q410959  Protein Family
# 3         Q419629  Protein Family
# 4         Q420863  Protein Family
# ...           ...             ...
# 24202  Q110196293  Protein Family
# 24203  Q110196295  Protein Family
# 24204  Q110196317  Protein Family
# 24205  Q110196328  Protein Family
# 24206  Q110196353  Protein Family
#
#                                                  ,name
# 0             voltage-gated chloride channel, subgroup
# 1                                    Calmodulin family
# 2             muscarinic acetylcholine receptor family
# 3           peroxisome proliferator-activated receptor
# 4                                             claudins
# ...                                                ...
# 24202                                      Protein NLP
# 24203  Homeobox-leucine zipper protein, class I, plant
# 24204              Protein of unknown function DUF6112
# 24205              WD40 repeat-containing protein SMU1
# 24206                      Arogenate dehydrogenase 1/2
#
# [24207 rows x 3 columns]
# 0.05960527261098226 to read in these .csv files

# %%
for file in filenames:
    test = pd.read_csv(file, sep="\t")
    print(test.head(3))
# Out:
#          :ID          ,:LABEL                    ,name
# 0   Q7559033  Chemical Hazard         solvent exposure
# 1  Q21973551  Chemical Hazard  sulfur mustard exposure
# 2  Q55696142  Chemical Hazard                      NaN
#        :ID  ,:LABEL                    ,name
# 0   Q68854  Disease                snakebite
# 1  Q119280  Disease  medullary sponge kidney
# 2  Q143790  Disease      Alien hand syndrome
#          :ID       ,:LABEL                                              ,name
# 0  Q24722105  Binding Site                     Germin, manganese binding site
# 1  Q24725852  Binding Site  Orn/DAP/Arg decarboxylase 2, pyridoxal-phospha...
# 2  Q24725899  Binding Site                  Leghaemoglobin, iron-binding site
#          :ID             ,:LABEL                           ,name
# 0  Q21694734  Biological Pathway            Vitamin D metabolism
# 1  Q28031274  Biological Pathway  Glycolysis and gluconeogenesis
# 2  Q29891990  Biological Pathway          MAPK signaling pathway
#        :ID             ,:LABEL        ,name
# 0    Q1057  Biological Process   metabolism
# 1   Q99974  Biological Process   mycorrhiza
# 2  Q134624  Biological Process  pollination
#        :ID ,:LABEL           ,name
# 0   Q30555    Gene  proto-oncogene
# 1  Q286987    Gene           ABCA1
# 2  Q390540    Gene           EDNRA
#        :ID  ,:LABEL      ,name
# 0  Q188611  Symptom  hypomania
# 1  Q653197  Symptom       rash
# 2  Q936070  Symptom    trismus
#      :ID               ,:LABEL         ,name
# 0  Q7365  Anatomical Structure  muscle organ
# 1  Q9377  Anatomical Structure        kidney
# 2  Q9609  Anatomical Structure          vein
#        :ID  ,:LABEL                                              ,name
# 0   Q63398  Protein                                     Chromogranin B
# 1  Q171604  Protein             Hydroxysteroid 11-beta dehydrogenase 1
# 2  Q205042  Protein  Atypical chemokine receptor 1 (Duffy blood group)
#          :ID           ,:LABEL            ,name
# 0   Q2007385  Structural Motif              NaN
# 1   Q5445279  Structural Motif  Ferredoxin fold
# 2  Q19903500  Structural Motif  Beta bulge loop
#         :ID         ,:LABEL                     ,name
# 0  Q1829843  Protein Domain               Bromodomain
# 1  Q5009288  Protein Domain                CBS domain
# 2  Q6718295  Protein Domain  mSin3 interaction domain
#          :ID             ,:LABEL  \
# 0   Q1012651  Molecular Function
# 1  Q14358843  Molecular Function
# 2  Q14599285  Molecular Function
#
#                                                ,name
# 0                            ribonuclease P activity
# 1  oxidoreductase activity, acting on paired dono...
# 2  oxidoreductase activity, acting on the CH-CH g...
#          :ID      ,:LABEL                                              ,name
# 0  Q24721060  Active Site     4-hydroxybenzoyl-CoA thioesterase, active site
# 1  Q24721301  Active Site     DNA/RNA non-specific endonuclease, active site
# 2  Q24721995  Active Site  Orotidine 5'-phosphate decarboxylase, active site
#       :ID             ,:LABEL            ,name
# 0  Q29548  Cellular Component  plasma membrane
# 1  Q30869  Cellular Component        nucleolus
# 2  Q61333  Cellular Component     X chromosome
#       :ID   ,:LABEL                ,name
# 0   Q2546  Compound    potassium bromide
# 1  Q19052  Compound        silver iodide
# 2  Q32703  Compound  aminomethylpropanol
#          :ID           ,:LABEL                ,name
# 0  Q28371440  Sequence Variant         DNMT3A P904L
# 1  Q28444966  Sequence Variant  EGFR Overexpression
# 2  Q28445004  Sequence Variant  NT5E OVEREXPRESSION
#        :ID            ,:LABEL             ,name
# 0  Q120569  Medical Specialty  gastroenterology
# 1  Q123028  Medical Specialty        pediatrics
# 2  Q162555  Medical Specialty          oncology
#        :ID         ,:LABEL                                     ,name
# 0  Q408477  Protein Family  voltage-gated chloride channel, subgroup
# 1  Q409145  Protein Family                         Calmodulin family
# 2  Q410959  Protein Family  muscarinic acetylcholine receptor family

# %%
for file in filenames:
    print(type(file))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# Create time stamp
timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 
start_time = time.time()

activesitefinal = pd.read_csv('files/csv/activesite.csv', sep="\t") 
anatomyfinal = pd.read_csv('files/csv/anatomy.csv', sep="\t") 
biologicalpathwayfinal = pd.read_csv('files/csv/biologicalpathway.csv', sep="\t")
biologicalprocessfinal = pd.read_csv('files/csv/biologicalprocess.csv', sep="\t")
bindingsitefinal = pd.read_csv('files/csv/bindingsite.csv', sep="\t")
cellularcomponentfinal = pd.read_csv('files/csv/cellularcomponent.csv', sep="\t")
chemicalhazardfinal = pd.read_csv('files/csv/chemicalhazard.csv', sep="\t")
compoundfinal = pd.read_csv('files/csv/compound.csv', sep="\t")
diseasefinal = pd.read_csv('files/csv/disease.csv', sep="\t")
genefinal = pd.read_csv('files/csv/gene.csv', sep="\t")
medicalspecialtyfinal = pd.read_csv('files/csv/medicalspecialty.csv', sep="\t")
molecularfunctionfinal = pd.read_csv('files/csv/molecularfunction.csv', sep="\t")
proteinfinal = pd.read_csv('files/csv/protein.csv', sep="\t")
proteindomainfinal = pd.read_csv('files/csv/proteindomain.csv', sep="\t")
proteinfamilyfinal = pd.read_csv('files/csv/proteinfamily.csv', sep="\t")
sequencevariantfinal = pd.read_csv('files/csv/sequencevariant.csv', sep="\t")
structuralmotiffinal = pd.read_csv('files/csv/structuralmotif.csv', sep="\t")
symptomfinal = pd.read_csv('files/csv/symptom.csv', sep="\t")


end_time = time.time() # 30 sec remote, 3 min local
print((end_time - start_time)/60, "to read in these .ndjson files")
# Out:
# 0.05106288989384969 to read in these .ndjson files

# %%
filenames = glob.glob(path + "/*.csv")
print('File names:', filenames)
# Out:
# File names: ['/home/sulhasan/Jan3-2022/files/csv/chemicalhazard.csv', '/home/sulhasan/Jan3-2022/files/csv/disease.csv', '/home/sulhasan/Jan3-2022/files/csv/bindingsite.csv', '/home/sulhasan/Jan3-2022/files/csv/biologicalpathway.csv', '/home/sulhasan/Jan3-2022/files/csv/biologicalprocess.csv', '/home/sulhasan/Jan3-2022/files/csv/gene.csv', '/home/sulhasan/Jan3-2022/files/csv/symptom.csv', '/home/sulhasan/Jan3-2022/files/csv/anatomy.csv', '/home/sulhasan/Jan3-2022/files/csv/protein.csv', '/home/sulhasan/Jan3-2022/files/csv/structuralmotif.csv', '/home/sulhasan/Jan3-2022/files/csv/proteindomain.csv', '/home/sulhasan/Jan3-2022/files/csv/molecularfunction.csv', '/home/sulhasan/Jan3-2022/files/csv/activesite.csv', '/home/sulhasan/Jan3-2022/files/csv/cellularcomponent.csv', '/home/sulhasan/Jan3-2022/files/csv/compound.csv', '/home/sulhasan/Jan3-2022/files/csv/sequencevariant.csv', '/home/sulhasan/Jan3-2022/files/csv/medicalspecialty.csv', '/home/sulhasan/Jan3-2022/files/csv/proteinfamily.csv']

# %%
# getting csv files from the folder MyProject
path = "/home/sulhasan/Jan3-2022/files/ndjson"

# read all the files with extension .ndjson
filenames = glob.glob(path + "/*.ndjson")
print('File names:', filenames)
# Out:
# File names: ['/home/sulhasan/Jan3-2022/files/ndjson/biologicalpathway.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/symptom.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/medicalspecialty.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/activesite.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/protein.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/disease.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/compound.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/bindingsite.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/proteinfamily.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/sequencevariant.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/proteindomain.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/molecularfunction.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/chemicalhazard.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/biologicalprocess.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/cellularcomponent.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/gene.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/structuralmotif.ndjson', '/home/sulhasan/Jan3-2022/files/ndjson/anatomy.ndjson']

# %%
# for loop to iterate all csv files
for file in filenames:
    print("\nReading file = ",file)
    print(pd.read_csv(file))
# Out:
# Reading file =  /home/sulhasan/Jan3-2022/files/ndjson/biologicalpathway.ndjson
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-9-dbbd0563e083> in <module>
#       2 for file in filenames:
#       3     print("\nReading file = ",file)
# ----> 4     print(pd.read_csv(file))
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2155     def read(self, nrows=None):
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#    2159             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 3481 fields in line 3, saw 10265

# %%
# Read in files (ndjson or csv)

import pandas as pd
import glob

# getting csv files from the folder MyProject
path = "/home/sulhasan/Jan3-2022/files/csv"

# read all the files with extension .csv
filenames = glob.glob(path + "*.csv")
print('File names:', filenames)

# for loop to iterate all csv files
for file in filenames:
    print("\nReading file = ",file)
    print(pd.read_csv(file))

# conversion to csv
timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 
start_time = time.time()

# for
    # read ndjson (chunksize = 5 on all)
    # write to csv
    # clean-up
    # print that node category
    # append to nodes.csv
    # clear chunksize variable after *test this with two small files

# %%
# Create time stamp
timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 
start_time = time.time()

activesite = pd.read_json('files/ndjson/activesite.ndjson', lines=True) 
anatomy = pd.read_json('files/ndjson/anatomy.ndjson', lines=True) 
bindingsite = pd.read_json('files/ndjson/bindingsite.ndjson', lines=True) 
biologicalpathway = pd.read_json('files/ndjson/biologicalpathway.ndjson', lines=True) 
biologicalprocess = pd.read_json('files/ndjson/biologicalprocess.ndjson', lines=True) 
cellularcomponent = pd.read_json('files/ndjson/cellularcomponent.ndjson', lines=True) 
chemicalhazard = pd.read_json('files/ndjson/chemicalhazard.ndjson', lines=True) 
disease = pd.read_json('files/ndjson/disease.ndjson', lines=True) 
medicalspecialty = pd.read_json('files/ndjson/medicalspecialty.ndjson', lines=True) 
molecularfunction = pd.read_json('files/ndjson/molecularfunction.ndjson', lines=True) 
proteindomain = pd.read_json('files/ndjson/proteindomain.ndjson', lines=True) 
proteinfamily = pd.read_json('files/ndjson/proteinfamily.ndjson', lines=True) 
sequencevariant = pd.read_json('files/ndjson/sequencevariant.ndjson', lines=True) 
structuralmotif = pd.read_json('files/ndjson/structuralmotif.ndjson', lines=True) 
symptom = pd.read_json('files/ndjson/symptom.ndjson', lines=True) 

end_time = time.time() # 30 sec remote, 3 min local
print((end_time - start_time)/60, "to read in these .ndjson files")
# Out:
# 0.6314284642537434 to read in these .ndjson files

# %%
timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 
start_time = time.time()

with open('files/csv/activesite.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index,row in activesite.iterrows():
        print(row['id']+"\tActive Site\t"+row['labels']['en']['value'], file = file)
activesitefinal = pd.read_csv('files/csv/activesite.csv', sep="\t")

end_time = time.time() # 30 sec remote
print((end_time - start_time)/60, "to convert these .ndjson to .csv")
# Out:
# 0.000388789176940918 to convert these .ndjson to .csv

# %%
timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 
start_time = time.time()

with open('files/csv/activesite.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index,row in activesite.iterrows():
        print(row['id']+"\tActive Site\t"+row['labels']['en']['value'], file = file)
activesitefinal = pd.read_csv('files/csv/activesite.csv', sep="\t")

with open('files/csv/anatomy.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index,row in anatomy.iterrows():
        print(row['id']+"\tAnatomical Structure\t"+row['labels']['en']['value'], file = file)
anatomyfinal = pd.read_csv('files/csv/anatomy.csv', sep="\t")

with open('files/csv/bindingsite.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index,row in bindingsite.iterrows():
        print(row['id']+"\tBinding Site\t"+row['labels']['en']['value'], file = file)
bindingsitefinal = pd.read_csv('files/csv/bindingsite.csv', sep="\t")

with open('files/csv/biologicalpathway.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index,row in biologicalpathway.iterrows():
        print(row['id']+"\tBiological Pathway\t"+row['labels']['en']['value'], file = file)
biologicalpathwayfinal = pd.read_csv('files/csv/biologicalpathway.csv', sep="\t")

with open('files/csv/biologicalprocess.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index, row in biologicalprocess.iterrows():
        if "en" in row["labels"].keys():
            print(row['id']+"\tBiological Process\t"+row['labels']['en']['value'], file = file)
        else:
            print(row["id"]+"\tBiological Process\t", file = file)
biologicalprocessfinal = pd.read_csv('files/csv/biologicalprocess.csv', sep="\t")

with open('files/csv/cellularcomponent.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index, row in cellularcomponent.iterrows():
        if "en" in row["labels"].keys():
            print(row['id']+"\tCellular Component\t"+row['labels']['en']['value'], file = file)
        else:
            print(row["id"]+"\tCellular Component\t", file = file)
cellularcomponentfinal = pd.read_csv('files/csv/cellularcomponent.csv', sep="\t")

with open('files/csv/chemicalhazard.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index, row in chemicalhazard.iterrows():
        if "en" in row["labels"].keys():
            print(row['id']+"\tChemical Hazard\t"+row['labels']['en']['value'], file = file)
        else:
            print(row["id"]+"\tChemical Hazard\t", file = file)
chemicalhazardfinal = pd.read_csv('files/csv/chemicalhazard.csv', sep="\t")

with open('files/csv/disease.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index, row in disease.iterrows():
        if "en" in row["labels"].keys():
            print(row['id']+"\tDisease\t"+row['labels']['en']['value'], file = file)
        else:
            print(row["id"]+"\tDisease\t", file = file)
diseasefinal = pd.read_csv('files/csv/disease.csv', sep="\t")

with open('files/csv/medicalspecialty.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index, row in medicalspecialty.iterrows():
        if "en" in row["labels"].keys():
            print(row['id']+"\tMedical Specialty\t"+row['labels']['en']['value'], file = file)
        else:
            print(row["id"]+"\tMedical Specialty\t", file = file)
medicalspecialtyfinal = pd.read_csv('files/csv/medicalspecialty.csv', sep="\t")

with open('files/csv/molecularfunction.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index,row in molecularfunction.iterrows():
        print(row['id']+"\tMolecular Function\t"+row['labels']['en']['value'], file = file)
molecularfunctionfinal = pd.read_csv('files/csv/molecularfunction.csv', sep="\t")

with open('files/csv/proteindomain.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index, row in proteindomain.iterrows():
        if "en" in row["labels"].keys():
            print(row['id']+"\tProtein Domain\t"+row['labels']['en']['value'], file = file)
        else:
            print(row["id"]+"\tProtein Domain\t", file = file)
proteindomainfinal = pd.read_csv('files/csv/proteindomain.csv', sep="\t")

with open('files/csv/proteinfamily.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index, row in proteinfamily.iterrows():
        if "en" in row["labels"].keys():
            print(row['id']+"\tProtein Family\t"+row['labels']['en']['value'], file = file)
        else:
            print(row["id"]+"\tProtein Family\t", file = file)
proteinfamilyfinal = pd.read_csv('files/csv/proteinfamily.csv', sep="\t")

with open('files/csv/sequencevariant.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index, row in sequencevariant.iterrows():
        if "en" in row["labels"].keys():
            print(row['id']+"\tSequence Variant\t"+row['labels']['en']['value'], file = file)
        else:
            print(row["id"]+"\tSequence Variant\t", file = file)
sequencevariantfinal = pd.read_csv('files/csv/sequencevariant.csv', sep="\t")

with open('files/csv/structuralmotif.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index, row in structuralmotif.iterrows():
        if "en" in row["labels"].keys():
            print(row['id']+"\tStructural Motif\t"+row['labels']['en']['value'], file = file)
        else:
            print(row["id"]+"\tStructural Motif\t", file = file)
structuralmotiffinal = pd.read_csv('files/csv/structuralmotif.csv', sep="\t")

with open('files/csv/symptom.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for index, row in symptom.iterrows():
        if "en" in row["labels"].keys():
            print(row['id']+"\tSymptom\t"+row['labels']['en']['value'], file = file)
        else:
            print(row["id"]+"\tSymptom\t", file = file)
symptomfinal = pd.read_csv('files/csv/symptom.csv', sep="\t")

end_time = time.time() # 30 sec remote
print((end_time - start_time)/60, "to convert these .ndjson to .csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0c9f84eceefd> in <module>
#      83     writer = csv.writer(file)
#      84     writer.writerow([':ID\t', ':LABEL\t', 'name'])
# ---> 85     for index,row in molecularfunction.iterrows():
#      86         print(row['id']+"\tMolecular Function\t"+row['labels']['en']['value'], file = file)
#      87 molecularfunctionfinal = pd.read_csv('files/csv/molecularfunction.csv', sep="\t")
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in iterrows(self)
#    1012         klass = self._constructor_sliced
#    1013         for k, v in zip(self.index, self.values):
# -> 1014             s = klass(v, index=columns, name=k)
#    1015             yield k, s
#    1016
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     327                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     328
# --> 329                 data = SingleBlockManager.from_array(data, index)
#     330
#     331         generic.NDFrame.__init__(self, data)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in from_array(cls, array, index)
#    1576         Constructor for if we have an array that is not yet a Block.
#    1577         """
# -> 1578         block = make_block(array, placement=slice(0, len(index)), ndim=1)
#    1579         return cls(block, index)
#    1580
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2735     if klass is None:
#    2736         dtype = dtype or values.dtype
# -> 2737         klass = get_block_type(values, dtype)
#    2738
#    2739     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values.dtype):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    2701     elif is_datetime64tz_dtype(values.dtype):
#    2702         cls = DatetimeTZBlock
# -> 2703     elif is_interval_dtype(dtype) or is_period_dtype(dtype):
#    2704         cls = ObjectValuesExtensionBlock
#    2705     elif is_extension_array_dtype(values.dtype):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_interval_dtype(arr_or_dtype)
#     519     True
#     520     """
# --> 521     if isinstance(arr_or_dtype, ExtensionDtype):
#     522         # GH#33400 fastpath for dtype object
#     523         return arr_or_dtype.type is Interval
#
# KeyboardInterrupt:

# %%
import pandas as pd
from io import StringIO

import time 
from datetime import datetime

import csv

# %%
import gc

a = 'test string'
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ad089e66a4f4> in <module>
#       3 a = 'test string'
#       4 del a
# ----> 5 print(a)
#
# NameError: name 'a' is not defined

# %%
timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 
start_time = time.time()
compound = pd.read_json('files/ndjson/compound.ndjson', lines=True, chunksize=5)
end_time = time.time() # 1 min remote
print((end_time - start_time)/60, "to read compound .ndjson") 

timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 
start_time = time.time()
with open('files/csv/compound.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for chunk in compound:
        for index,row in chunk.iterrows():
            if 'en' in row['labels'].keys():
                print(row['id']+"\tCompound\t"+row['labels']['en']['value'], file = file)
            else: 
                print(row['id']+"\tCompound\t", file = file)
end_time = time.time() # 32 min remote
print((end_time - start_time)/60, "to convert compound .ndjson to .csv")

# %reset -f 
# jupyter specific (lpython)
# https://ipython.readthedocs.io/en/stable/interactive/magics.html?highlight=magic#magic-reset

import pandas as pd
from io import StringIO
import time 
from datetime import datetime
import csv

timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 
start_time = time.time()
gene = pd.read_json('files/ndjson/gene.ndjson', lines=True, chunksize=5)
end_time = time.time() # 15.5 min remote
print((end_time - start_time)/60, "to read gene .ndjson")

timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 
start_time = time.time()
with open('files/csv/gene.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for chunk in gene:
        for index,row in chunk.iterrows():
            if 'en' in row['labels'].keys():
                print(row['id']+"\tGene\t"+row['labels']['en']['value'], file = file)
            else: 
                print(row['id']+"\tGene\t", file = file)
end_time = time.time() # 39 min remote
print((end_time - start_time)/60, "to convert gene .ndjson to .csv")

# %reset -f 

import pandas as pd
from io import StringIO
import time 
from datetime import datetime
import csv

timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 
start_time = time.time()
protein = pd.read_json('files/ndjson/protein.ndjson', lines=True, chunksize=5)
end_time = time.time() # 2 min remote
print((end_time - start_time)/60, "to read protein .ndjson")

timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 
start_time = time.time()
with open('files/csv/protein.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID\t', ':LABEL\t', 'name'])
    for chunk in protein:
        for index,row in chunk.iterrows():
            if 'en' in row['labels'].keys():
                print(row['id']+"\tProtein\t"+row['labels']['en']['value'], file = file)
            else: 
                print(row['id']+"\tProtein\t", file = file)
end_time = time.time() # 33 min remote
print((end_time - start_time)/60, "to convert protein .ndjson to .csv")
# Out:
# 1.4289645353953044 to read compound .ndjson

# %%
nodes_mike = pd.read_csv('files/mmayers_files/nodes_2019-09-03.csv')

# %%
nodes_mike.head()

# %%
nodes_mike[':LABEL'].value_counts() # 19 categories

# %%
activesitefinal = pd.read_csv('files/csv/activesite.csv', sep="\t") 
anatomyfinal = pd.read_csv('files/csv/anatomy.csv', sep="\t") 
biologicalpathwayfinal = pd.read_csv('files/csv/biologicalpathway.csv', sep="\t")
biologicalprocessfinal = pd.read_csv('files/csv/biologicalprocess.csv', sep="\t")
bindingsitefinal = pd.read_csv('files/csv/bindingsite.csv', sep="\t")
cellularcomponentfinal = pd.read_csv('files/csv/cellularcomponent.csv', sep="\t")
chemicalhazardfinal = pd.read_csv('files/csv/chemicalhazard.csv', sep="\t")
compoundfinal = pd.read_csv('files/csv/compound.csv', sep="\t")
diseasefinal = pd.read_csv('files/csv/disease.csv', sep="\t")
genefinal = pd.read_csv('files/csv/gene.csv', sep="\t")
medicalspecialtyfinal = pd.read_csv('files/csv/medicalspecialty.csv', sep="\t")
molecularfunctionfinal = pd.read_csv('files/csv/molecularfunction.csv', sep="\t")
proteinfinal = pd.read_csv('files/csv/protein.csv', sep="\t")
proteindomainfinal = pd.read_csv('files/csv/proteindomain.csv', sep="\t")
proteinfamilyfinal = pd.read_csv('files/csv/proteinfamily.csv', sep="\t")
sequencevariantfinal = pd.read_csv('files/csv/sequencevariant.csv', sep="\t")
structuralmotiffinal = pd.read_csv('files/csv/structuralmotif.csv', sep="\t")
symptomfinal = pd.read_csv('files/csv/symptom.csv', sep="\t")

# %%
# repeat line for this node file
# Out:
# Biological Process 	 3562
# Gene 			 89348
# Protein Family 		 2441
# Compound 		 18718
# Disease 		 337
# Protein Domain 		 1117
# Molecular Function 	 1307
# Biological Pathway 	 52
# Sequence Variant 	 80
# Cellular Component 	 511
# Chemical Hazard 	 0
# Anatomical Structure 	 368
# Active Site 		 9
# Structural Motif 	 35
# Binding Site 		 10
# Medical Specialty 	 24
#
# Protein 		 63604

# %%
nodes = pd.concat([activesitefinal, anatomyfinal, biologicalpathwayfinal, 
                   biologicalprocessfinal, bindingsitefinal, cellularcomponentfinal,
                   chemicalhazardfinal, compoundfinal, diseasefinal, 
                   genefinal, medicalspecialtyfinal, molecularfunctionfinal, 
                   proteinfinal, proteindomainfinal, proteinfamilyfinal, 
                   sequencevariantfinal, structuralmotiffinal, symptomfinal], axis=0)
nodes.to_csv('nodes.csv')

# %%
nodes.head()
# Out:
#          :ID      ,:LABEL                                              ,name
# 0  Q24721060  Active Site     4-hydroxybenzoyl-CoA thioesterase, active site
# 1  Q24721301  Active Site     DNA/RNA non-specific endonuclease, active site
# 2  Q24721995  Active Site  Orotidine 5'-phosphate decarboxylase, active site
# 3  Q24740369  Active Site            Adenylosuccinate synthase,  active site
# 4  Q24770253  Active Site                  Membrane dipeptidase, active site

# %%
nodes.tail()
# Out:
#             :ID  ,:LABEL                          ,name
# 324   Q56233069  Symptom                  Tetanus triad
# 325   Q58145981  Symptom                    apragmatism
# 326   Q67135693  Symptom  rejection sensitive dysphoria
# 327   Q96470164  Symptom            identity alteration
# 328  Q107355983  Symptom          Paradoxical breathing

# %% [markdown]
# ## edges.csv

# %%
edges_mike.head() # qualifier NaN (both head and tail)
# Out:
#   :START_ID  :END_ID                              :TYPE qualifier inner1
# 0   Q144085  Q412496  SIGNIFICANT_DRUG_INTERACTION_CdiC       NaN    NaN
# 1  Q3712521  Q419394  SIGNIFICANT_DRUG_INTERACTION_CdiC       NaN    NaN
# 2   Q410061  Q417597  SIGNIFICANT_DRUG_INTERACTION_CdiC       NaN    NaN
# 3   Q174259    Q7739  SIGNIFICANT_DRUG_INTERACTION_CdiC       NaN    NaN
# 4  Q3791612   Q41576  SIGNIFICANT_DRUG_INTERACTION_CdiC       NaN    NaN

# %%
edges_mike.tail()
# Out:
#         :START_ID    :END_ID              :TYPE qualifier     inner1
# 614760  Q21112306  Q14878358  UP_REGULATES_GuBP       NaN  Q14761970
# 614761  Q21111886  Q14864067  UP_REGULATES_GuBP       NaN  Q14863719
# 614762  Q11705457  Q14864067  UP_REGULATES_GuBP       NaN  Q14863719
# 614763    Q423701  Q14878358  UP_REGULATES_GuBP       NaN  Q14761970
# 614764   Q3616234  Q14878358  UP_REGULATES_GuBP       NaN  Q14761970

# %%
edges_mike[':TYPE'].value_counts() # number of categories ?
# Out:
# BIOLOGICAL_PROCESS_GbpBP               173157
# CELL_COMPONENT_GccCC                   107182
# MOLECULAR_FUNCTION_GmfMF                90473
# HAS_PART_GhpPD                          30796
# HAS_PART_PWhpG                          27935
# TREATS_CtD                              26928
# HAS_PART_PFhpG                          19086
# UP_REGULATES_GuBP                       16705
# REGULATES_GregBP                        14390
# HAS_PART_PWhpBP                         12445
# DOWN_REGULATES_GdBP                     11530
# SYMPTOMS_CHsyD                          10564
# HAS_ROLE_CrCR                            9841
# HAS_PART_BPhpC                           9298
# MEDICAL_SPECIALTY_DmsMS                  7057
# GENETIC_ASSOCIATION_DaG                  6506
# HAS_PART_PFhpPD                          6395
# HAS_PART_GhpSS                           4153
# HAS_PART_PWhpC                           3612
# PHYSICALLY_INTERACTS_WITH_GiwC           3608
# SYMPTOMS_CHsyS                           2970
# VARIANT_OF_VvG                           2662
# INHIBITS_CiG                             2366
# HAS_PART_GhpSM                           2260
# HAS_PART_PFhpSS                          1483
# POSITIVE_DIAGNOSTIC_PREDICTOR_VpdD       1409
# ACTIVATES_CacG                           1326
# AFFLICTS_CHafA                           1253
# SIGNIFICANT_DRUG_INTERACTION_CdiC        1060
# HAS_PART_GhpAS                           1053
# HAS_PART_GhpBS                            861
# POSITIVE_THERAPEUTIC_PREDICTOR_VptC       789
# ANATOMICAL_LOCATION_DlA                   739
# NEGATIVE_THERAPEUTIC_PREDICTOR_VntC       600
# HAS_CAUSE_CHhcC                           569
# HAS_PART_PDhpSS                           416
# HAS_PART_PFhpAS                           289
# SYMPTOMS_DsyS                             285
# HAS_PART_PFhpBS                           237
# BINDS_CbG                                 156
# NEGATIVE_DIAGNOSTIC_PREDICTOR_VndD        145
# CELL_COMPONENT_GccA                       131
# TREATS_CtCH                                45
# Name: :TYPE, dtype: int64

# %%
# TREATS_CtCH  = Compound treats Chemical Hazard
# CELL_COMPONENT_GccA = Gene cell component Anatomy

# Compile all nodes files into one .ndjson => edges.ndjson
# for loop that walks through each item page
# searches for any node category (19)
## P681 = Cell Component
### QID of Item page? Q21172808
### QID of statement? Q14645596, Q1385443
# => 2 rows

test = edges_mike[edges_mike[':TYPE'].str.contains('CELL_COMPONENT_GccA')]
test
# Out:
#         :START_ID :END_ID                :TYPE qualifier inner1
# 550744  Q21172808   Q7868  CELL_COMPONENT_GccA       NaN    NaN
# 550745  Q21136304   Q7868  CELL_COMPONENT_GccA       NaN    NaN
# 550746  Q21141302   Q7868  CELL_COMPONENT_GccA       NaN    NaN
# 550747  Q21141766   Q7868  CELL_COMPONENT_GccA       NaN    NaN
# 550748  Q21135810   Q7868  CELL_COMPONENT_GccA       NaN    NaN
# ...           ...     ...                  ...       ...    ...
# 550870  Q21116920   Q7868  CELL_COMPONENT_GccA       NaN    NaN
# 550871  Q21123790   Q7868  CELL_COMPONENT_GccA       NaN    NaN
# 550872  Q21124394   Q7868  CELL_COMPONENT_GccA       NaN    NaN
# 550873    Q425649   Q7868  CELL_COMPONENT_GccA       NaN    NaN
# 550874  Q21097549   Q7868  CELL_COMPONENT_GccA       NaN    NaN
#
# [131 rows x 5 columns]

# %%
gene.tail()
# Out:
#        type         id                                             labels  \
# 89343  item  Q32022523  {'en': {'language': 'en', 'value': 'pseudogene...
# 89344  item  Q32022533  {'en': {'language': 'en', 'value': 'pseudogene...
# 89345  item  Q33133531     {'en': {'language': 'en', 'value': 'MASCRNA'}}
# 89346  item  Q33133587  {'en': {'language': 'en', 'value': 'metal resp...
# 89347  item  Q34570812     {'en': {'language': 'en', 'value': 'Mascrna'}}
#
#                                             descriptions  \
# 89343  {'en': {'language': 'en', 'value': 'microbial ...
# 89344  {'en': {'language': 'en', 'value': 'microbial ...
# 89345  {'en': {'language': 'en', 'value': 'small cond...
# 89346  {'en': {'language': 'en', 'value': 'gene trans...
# 89347  {'en': {'language': 'en', 'value': 'small cond...
#
#                                                  aliases  \
# 89343  {'en': [{'language': 'en', 'value': 'CPn0954'}...
# 89344  {'en': [{'language': 'en', 'value': 'CPn0356'}...
# 89345  {'en': [{'language': 'en', 'value': 'MALAT1-as...
# 89346                                                 {}
# 89347  {'en': [{'language': 'en', 'value': 'Malat1-as...
#
#                                                   claims  \
# 89343  {'P351': [{'mainsnak': {'snaktype': 'value', '...
# 89344  {'P351': [{'mainsnak': {'snaktype': 'value', '...
# 89345  {'P31': [{'mainsnak': {'snaktype': 'value', 'p...
# 89346  {'P31': [{'mainsnak': {'snaktype': 'value', 'p...
# 89347  {'P639': [{'mainsnak': {'snaktype': 'value', '...
#
#                                                sitelinks   lastrevid
# 89343                                                 {}   949751625
# 89344                                                 {}   948903352
# 89345  {'enwiki': {'site': 'enwiki', 'title': 'Malat1...  1500223206
# 89346  {'enwikiversity': {'site': 'enwikiversity', 't...  1551023185
# 89347                                                 {}  1165429673

# %%
Q21172808 = gene[gene['id'].str.contains('Q21172808')] # example of interest 
Q21172808 # not in file, but should be?
# Out:
# Empty DataFrame
# Columns: [type, id, labels, descriptions, aliases, claims, sitelinks, lastrevid]
# Index: []

# %%
Q34570812 = gene[gene['id'].str.contains('Q34570812')] # we know this is in gene
Q34570812
# Out:
#        type         id                                          labels  \
# 89347  item  Q34570812  {'en': {'language': 'en', 'value': 'Mascrna'}}
#
#                                             descriptions  \
# 89347  {'en': {'language': 'en', 'value': 'small cond...
#
#                                                  aliases  \
# 89347  {'en': [{'language': 'en', 'value': 'Malat1-as...
#
#                                                   claims sitelinks   lastrevid
# 89347  {'P639': [{'mainsnak': {'snaktype': 'value', '...        {}  1165429673

# %%
# new issue: where is cellular component? instance of protein (artifact?)
## should have PccA instead of GccA?
### collapsing gene and protein (explicitly note this in documentation)
#### may be viewable in sparql queries

# %%
Q21172808 = protein[protein['id'].str.contains('Q21172808')] # example of interest 
Q21172808 # not in file, but should be *
# Out:
# Empty DataFrame
# Columns: [type, id, labels, descriptions, aliases, claims, sitelinks, lastrevid]
# Index: []

# %%
protein.tail()
# Out:
#        type         id                                             labels  \
# 63599  item  Q33087645  {'en': {'language': 'en', 'value': 'Olfactory ...
# 63600  item  Q33090878  {'en': {'language': 'en', 'value': 'Pregnancy-...
# 63601  item  Q33090900  {'en': {'language': 'en', 'value': 'CDNA seque...
# 63602  item  Q33526270  {'en': {'language': 'en', 'value': 'Leukocyte ...
# 63603  item  Q34708335  {'en': {'language': 'en', 'value': 'Cation cha...
#
#                                             descriptions  \
# 63599  {'en': {'language': 'en', 'value': 'mammalian ...
# 63600  {'en': {'language': 'en', 'value': 'mammalian ...
# 63601  {'en': {'language': 'en', 'value': 'mammalian ...
# 63602  {'en': {'language': 'en', 'value': 'mammalian ...
# 63603  {'en': {'language': 'en', 'value': 'mammalian ...
#
#                                                  aliases  \
# 63599  {'en': [{'language': 'en', 'value': 'olfactory...
# 63600  {'en': [{'language': 'en', 'value': 'carcinoem...
# 63601  {'en': [{'language': 'en', 'value': 'cDNA sequ...
# 63602  {'en': [{'language': 'en', 'value': 'CD85 anti...
# 63603  {'en': [{'language': 'en', 'value': 'Gm16432'}...
#
#                                                   claims sitelinks   lastrevid
# 63599  {'P702': [{'mainsnak': {'snaktype': 'value', '...        {}  1550040995
# 63600  {'P702': [{'mainsnak': {'snaktype': 'value', '...        {}  1549936703
# 63601  {'P702': [{'mainsnak': {'snaktype': 'value', '...        {}  1550079906
# 63602  {'P705': [{'mainsnak': {'snaktype': 'value', '...        {}  1229620193
# 63603  {'P352': [{'mainsnak': {'snaktype': 'value', '...        {}  1019879253

# %%
Q33087645 = protein[protein['id'].str.contains('Q33087645')] 
Q33087645 # 3 rows for GccA, in description
# Out:
#        type         id                                             labels  \
# 63599  item  Q33087645  {'en': {'language': 'en', 'value': 'Olfactory ...
#
#                                             descriptions  \
# 63599  {'en': {'language': 'en', 'value': 'mammalian ...
#
#                                                  aliases  \
# 63599  {'en': [{'language': 'en', 'value': 'olfactory...
#
#                                                   claims sitelinks   lastrevid
# 63599  {'P702': [{'mainsnak': {'snaktype': 'value', '...        {}  1550040995

# %%
pd.options.display.max_colwidth = 10000 # adjust after?
print(Q33087645['claims']) # search directly for P681 in claims

# Figure out what all top-level keys are
# Outputs like a python object and look at dictionary keys --> need all of these
## parse as a claims string
# Out:
# 63599    {'P702': [{'mainsnak': {'snaktype': 'value', 'property': 'P702', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 18300085, 'id': 'Q18300085'}, 'type': 'wikibase-entityid'}, 'datatype': 'wikibase-item'}, 'type': 'statement', 'id': 'Q33087645$0D293ED5-E226-4115-A7B2-F7595BB2C195', 'rank': 'normal', 'references': [{'hash': '33cc59c62a30319632fb6b6bdf6616457c048538', 'snaks': {'P248': [{'snaktype': 'value', 'property': 'P248', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 905695, 'id': 'Q905695'}, 'type': 'wikibase-entityid'}, 'datatype': 'wikibase-item'}], 'P813': [{'snaktype': 'value', 'property': 'P813', 'datavalue': {'value': {'time': '+2021-11-17T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'type': 'time'}, 'datatype': 'time'}], 'P352': [{'snaktype': 'value', 'property': 'P352', 'datavalue': {'value': 'Q9EQA0', 'type': 'string'}, 'datatype': 'external-id'}]}, 'snaks-order': ['P248', 'P813', 'P352']}]}], 'P352': [{'mainsnak': {'snaktype': 'value', 'property': 'P352', 'datavalue': {'value': 'Q9EQA0', 'type': 'string'}, 'datatype': 'external-id'}, 'type': 'statement', 'id': 'Q33087645$E2DC96F7-DD2F-4C59-AC39-D71816262774', 'rank': 'normal', 'references': [{'hash': '33cc59c62a30319632fb6b6bdf6616457c048538', 'snaks': {'P248': [{'snaktype': 'value', 'property': 'P248', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 905695, 'id': 'Q905695'}, 'type': 'wikibase-entityid'}, 'datatype': 'wikibase-item'}], 'P813': [{'snaktype': 'value', 'property': 'P813', 'datavalue': {'value': {'time': '+2021-11-17T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'type': 'time'}, 'datatype': 'time'}], 'P352': [{'snaktype': 'value', 'property': 'P352', 'datavalue': {'value': 'Q9EQA0', 'type': 'string'}, 'datatype': 'external-id'}]}, 'snaks-order': ['P248', 'P813', 'P352']}]}], 'P637': [{'mainsnak': {'snaktype': 'value', 'property': 'P637', 'datavalue': {'value': 'NP_666652', 'type': 'string'}, 'datatype': 'external-id'}, 'type': 'statement', 'id': 'Q33087645$DAF949AE-6F88-4859-B54B-83EC4C435E6A', 'rank': 'normal', 'references': [{'hash': 'a4f0f898792dc288ea32c7cea0d4c50eafefc325', 'snaks': {'P248': [{'snaktype': 'value', 'property': 'P248', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 20641742, 'id': 'Q20641742'}, 'type': 'wikibase-entityid'}, 'datatype': 'wikibase-item'}], 'P813': [{'snaktype': 'value', 'property': 'P813', 'datavalue': {'value': {'time': '+2021-09-07T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'type': 'time'}, 'datatype': 'time'}], 'P351': [{'snaktype': 'value', 'property': 'P351', 'datavalue': {'value': '258433', 'type': 'string'}, 'datatype': 'external-id'}]}, 'snaks-order': ['P248', 'P813', 'P351']}]}], 'P703': [{'mainsnak': {'snaktype': 'value', 'property': 'P703', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 83310, 'id': 'Q83310'}, 'type': 'wikibase-entityid'}, 'datatype': 'wikibase-item'}, 'type': 'statement', 'id': 'Q33087645$932FECFC-3A9A-4627-93EA-684F1B80F916', 'rank': 'normal', 'references': [{'hash': '33cc59c62a30319632fb6b6bdf6616457c048538', 'snaks': {'P248': [{'snaktype': 'value', 'property': 'P248', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 905695, 'id': 'Q905695'}, 'type': 'wikibase-entityid'}, 'datatype': 'wikibase-item'}], 'P813': [{'snaktype': 'value', 'property': 'P813', 'datavalue': {'value': {'time': '+2021-11-17T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'type': 'time'}, 'datatype': 'time'}], 'P352': [{'snaktype': 'value', 'property': 'P352', 'datavalue': {'value': 'Q9EQA0', 'type': 'string'}, 'datatype': 'external-id'}]}, 'snaks-order': ['P248', 'P813', 'P352']}]}], 'P680': [{' ...
# Name: claims, dtype: object

# %%
edges_mike = pd.read_csv('files/mmayers_files/edges_2019-09-03.csv')
